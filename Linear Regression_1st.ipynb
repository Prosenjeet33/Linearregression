# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import xlrd

# Importing the dataset
df = pd.read_excel("/Users/prosenjeet.saha/Desktop/data.xlsx")

# %%
df.head()
# Out:
#     appl_id  TOT_UNSEC_ENQ_12M  lac2_ln_live_enq_rat_2y  BAL_SAMT_OVR  \
# 0  14089715                  6                 0.333333      0.868034
# 1  14089716                  1                 0.500000      0.145975
# 2  14089720                  3                 0.333333      0.519140
# 3  14094736                 10                 0.900000      0.270773
# 4  14096549                  6                 0.250000      0.000000
#
#    CURR_LIABI__C_PY  AGE_IN_BUREAU  BTO  industry_bin  asset_turnover_rat_rat  \
# 0              10.0            7.0  0.0           2.0                0.908465
# 1               3.0            3.0  0.0           4.0                1.210538
# 2               7.0            3.0  0.0           NaN                1.329403
# 3               4.0           11.0  0.0           2.0                0.638542
# 4               3.0            7.0  0.0           2.0                1.706631
#
#    lac2_ln_enq_amt_rat_5y  ...  BAL_SAMT_lastloan  TOT_5lac_enq_amt_12m  \
# ...

# %%
df.drop(['Industy Type' , 'city' , 'Industry Sector'] , axis=1)
# Out:
#         appl_id  TOT_UNSEC_ENQ_12M  lac2_ln_live_enq_rat_2y  BAL_SAMT_OVR  \
# 0      14089715                  6                 0.333333      0.868034
# 1      14089716                  1                 0.500000      0.145975
# 2      14089720                  3                 0.333333      0.519140
# 3      14094736                 10                 0.900000      0.270773
# 4      14096549                  6                 0.250000      0.000000
# ...         ...                ...                      ...           ...
# 29467  42953070                  0                      NaN           NaN
# 29468  42953299                  6                 0.000000           NaN
# 29469  42953450                  0                      NaN           NaN
# 29470  42953461                  1                 0.411765      0.584245
# 29471  42953501                  0                      NaN           NaN
#
#        CURR_LIABI__C_PY  AGE_IN_BUREAU     BTO  industry_bin  \
# ...

# %%
df.fillna(df.mean(), inplace=True)

# %%
print(df.shape)
# Out:
# (29472, 22)

# %%
print(df.isnull().sum())
# Out:
# appl_id                        0
# TOT_UNSEC_ENQ_12M              0
# lac2_ln_live_enq_rat_2y        0
# BAL_SAMT_OVR                   0
# CURR_LIABI__C_PY               0
# AGE_IN_BUREAU                  0
# BTO                            0
# industry_bin                   0
# asset_turnover_rat_rat         0
# lac2_ln_enq_amt_rat_5y         0
# TM_SN_FIRST_LIVE_5lac          0
# TM_SN_FIRST_LOAN_CC            0
# BAL_SAMT_lastloan              0
# TOT_5lac_enq_amt_12m           0
# NET_WORTH__C_rat               0
# bor_sales_rat_cy               0
# WOR_CAPITAL_GAP__C_avg         0
# AVG_INT_PURCH_DAYS_pl_2y       0
# city                           0
# Industy Type                2708
# Industry Sector                0
# Risk Score                     0
# dtype: int64

# %%
import pandas
from sklearn import linear_model
X = df[['CURR_LIABI__C_PY', 'NET_WORTH__C_rat' , 'AGE_IN_BUREAU']]
y = df['Risk Score']

regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [ 2.50275901 -5.1838086   3.61299293]

# %%
import pandas
from sklearn import linear_model
X = df[['TOT_UNSEC_ENQ_12M', 'BAL_SAMT_OVR']]
y = df['Risk Score']

regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [-3.38367915e+00 -3.33868924e-03]

# %%
import pandas
from sklearn import linear_model
X = df[['asset_turnover_rat_rat', 'BAL_SAMT_OVR']]
y = df['Risk Score']

regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [-0.00011141 -0.00357371]

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['asset_turnover_rat_rat', 'BAL_SAMT_OVR']]

scaledX = scale.fit_transform(X)

print(scaledX)
# Out:
# [[-6.35794313e-03 -1.31075074e-03]
#  [-5.90204297e-03 -1.02010223e-02]
#  [-5.72264663e-03 -5.60646636e-03]
#  ...
#  [-5.75444038e-03 -1.77703493e-17]
#  [-5.75689098e-03 -4.80486762e-03]
#  [-6.18233479e-03 -1.77703493e-17]]

# %%
X = df[['asset_turnover_rat_rat', 'BAL_SAMT_OVR']]
y = df['Risk Score']

scaledX = scale.fit_transform(X)

regr = linear_model.LinearRegression()
regr.fit(scaledX, y)
scaled = scale.transform([[2300, 1.3]])

appl_id = regr.predict([scaled[0]])
print(appl_id)
# Out:
# [704.67509649]

# %%
plt.hist
plt.show()

# %%
print(df.keys())
# Out:
# Index(['appl_id', 'TOT_UNSEC_ENQ_12M', 'lac2_ln_live_enq_rat_2y',
#        'BAL_SAMT_OVR', 'CURR_LIABI__C_PY', 'AGE_IN_BUREAU', 'BTO',
#        'industry_bin', 'asset_turnover_rat_rat', 'lac2_ln_enq_amt_rat_5y',
#        'TM_SN_FIRST_LIVE_5lac', 'TM_SN_FIRST_LOAN_CC', 'BAL_SAMT_lastloan',
#        'TOT_5lac_enq_amt_12m', 'NET_WORTH__C_rat', 'bor_sales_rat_cy',
#        'WOR_CAPITAL_GAP__C_avg', 'AVG_INT_PURCH_DAYS_pl_2y', 'city',
#        'Industy Type', 'Industry Sector', 'Risk Score'],
#       dtype='object')

# %%
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.df()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
# the independent variables set
X = df[['TOT_UNSEC_ENQ_12M', 'lac2_ln_live_enq_rat_2y', 'BAL_SAMT_OVR' , 'CURR_LIABI__C_PY' , 'AGE_IN_BUREAU' , 'BTO' , 'industry_bin' ,
       'asset_turnover_rat_rat' , 'lac2_ln_enq_amt_rat_5y' , 'TM_SN_FIRST_LIVE_5lac' , 'TM_SN_FIRST_LOAN_CC' , 'BAL_SAMT_lastloan' , 'TOT_5lac_enq_amt_12m' ,
       'NET_WORTH__C_rat' , 'bor_sales_rat_cy' , 'WOR_CAPITAL_GAP__C_avg' , 'AVG_INT_PURCH_DAYS_pl_2y'  , 'Risk Score']]
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
print(vif_data)
# Out:
#                      feature        VIF
# 0          TOT_UNSEC_ENQ_12M   2.352558
# 1    lac2_ln_live_enq_rat_2y   2.105566
# 2               BAL_SAMT_OVR   1.000305
# 3           CURR_LIABI__C_PY   6.001670
# 4              AGE_IN_BUREAU   8.573307
# 5                        BTO   1.611540
# 6               industry_bin   9.619135
# 7     asset_turnover_rat_rat   1.000556
# 8     lac2_ln_enq_amt_rat_5y   1.217422
# 9      TM_SN_FIRST_LIVE_5lac   3.576824
# 10       TM_SN_FIRST_LOAN_CC   9.660970
# 11         BAL_SAMT_lastloan   1.002212
# 12      TOT_5lac_enq_amt_12m   8.436842
# 13          NET_WORTH__C_rat   5.394397
# 14          bor_sales_rat_cy   1.158538
# 15    WOR_CAPITAL_GAP__C_avg   5.633325
# 16  AVG_INT_PURCH_DAYS_pl_2y   9.592486
# 17                Risk Score  27.577259

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.pairplot(df, kind="kde")

# %%
df.corr()
# Out:
#                            appl_id  TOT_UNSEC_ENQ_12M  \
# appl_id                   1.000000           0.028038
# TOT_UNSEC_ENQ_12M         0.028038           1.000000
# lac2_ln_live_enq_rat_2y   0.051915          -0.230973
# BAL_SAMT_OVR              0.001572           0.000612
# CURR_LIABI__C_PY         -0.056445           0.237043
# AGE_IN_BUREAU             0.036171           0.235366
# BTO                       0.518775           0.065413
# industry_bin              0.025273          -0.053323
# asset_turnover_rat_rat    0.007547           0.003144
# lac2_ln_enq_amt_rat_5y    0.015070          -0.119516
# TM_SN_FIRST_LIVE_5lac     0.026455           0.101389
# TM_SN_FIRST_LOAN_CC      -0.009768           0.131339
# BAL_SAMT_lastloan        -0.007153           0.015591
# TOT_5lac_enq_amt_12m     -0.014011           0.506978
# NET_WORTH__C_rat         -0.036840           0.100887
# bor_sales_rat_cy         -0.012042           0.047902
# ...

# %%
X = df[['TOT_UNSEC_ENQ_12M', 'lac2_ln_live_enq_rat_2y', 'BAL_SAMT_OVR' , 'CURR_LIABI__C_PY' , 'AGE_IN_BUREAU' , 'BTO' , 'industry_bin' ,
       'asset_turnover_rat_rat' , 'lac2_ln_enq_amt_rat_5y' , 'TM_SN_FIRST_LIVE_5lac' , 'TM_SN_FIRST_LOAN_CC' , 'BAL_SAMT_lastloan' , 'TOT_5lac_enq_amt_12m' ,
       'NET_WORTH__C_rat' , 'bor_sales_rat_cy' , 'WOR_CAPITAL_GAP__C_avg' , 'AVG_INT_PURCH_DAYS_pl_2y']]
y = df['Risk Score']
regr = linear_model.LinearRegression()
regr.fit(X, y)

print(regr.coef_)
# Out:
# [-3.34320059e+00  2.19394521e+01 -4.91257898e-03  5.55929655e+00
#   4.65488464e+00  1.06967615e-01 -2.81328287e+01 -5.73258802e-05
#   2.55159892e+00  1.04120986e-02 -1.56431144e-05 -2.86356254e-05
#  -6.15138277e+00 -1.92352700e+00 -4.59500532e+00 -4.14112128e+00
#  -1.93548405e-02]

# %%
corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
corrMatrix = df.corr()
print (corrMatrix)
# Out:
#                            appl_id  TOT_UNSEC_ENQ_12M  \
# appl_id                   1.000000           0.028038
# TOT_UNSEC_ENQ_12M         0.028038           1.000000
# lac2_ln_live_enq_rat_2y   0.051915          -0.230973
# BAL_SAMT_OVR              0.001572           0.000612
# CURR_LIABI__C_PY         -0.056445           0.237043
# AGE_IN_BUREAU             0.036171           0.235366
# BTO                       0.518775           0.065413
# industry_bin              0.025273          -0.053323
# asset_turnover_rat_rat    0.007547           0.003144
# lac2_ln_enq_amt_rat_5y    0.015070          -0.119516
# TM_SN_FIRST_LIVE_5lac     0.026455           0.101389
# TM_SN_FIRST_LOAN_CC      -0.009768           0.131339
# BAL_SAMT_lastloan        -0.007153           0.015591
# TOT_5lac_enq_amt_12m     -0.014011           0.506978
# NET_WORTH__C_rat         -0.036840           0.100887
# bor_sales_rat_cy         -0.012042           0.047902
# ...

# %%
#separate the other attributes from the predicting attribute
x = df.drop('industry_bin',axis=1)
#separte the predicting attribute into Y for model training 
y = ['Risk Score']

# %%
x.shape
# Out:
# (29472, 21)

# %%
x.shape
# Out:
# (29472, 21)

# %%
x.shape
# Out:
# (648384, 1)

# %%
#separate the other attributes from the predicting attribute
x = df.drop('Risk Score',axis=1)
#separte the predicting attribute into Y for model training 
y = ['Risk Score']

# %%
#separate the other attributes from the predicting attribute
x = df.drop('Risk Score',axis=1)
#separte the predicting attribute into Y for model training 
y = ['Risk Score']

# %%
#separate the other attributes from the predicting attribute
x = df.drop('Risk Score',axis=1)
#separte the predicting attribute into Y for model training 
y = ['Risk Score']

# %%
#separate the other attributes from the predicting attribute
x = df.drop('Risk Score',axis=1)
#separte the predicting attribute into Y for model training 
y = ['Risk Score']

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         appl_id  TOT_UNSEC_ENQ_12M  lac2_ln_live_enq_rat_2y  BAL_SAMT_OVR  \
# 0      14089715                  6                 0.333333      0.868034
# 1      14089716                  1                 0.500000      0.145975
# 2      14089720                  3                 0.333333      0.519140
# 3      14094736                 10                 0.900000      0.270773
# 4      14096549                  6                 0.250000      0.000000
# ...         ...                ...                      ...           ...
# 29467  42953070                  0                 0.488233      0.974492
# 29468  42953299                  6                 0.000000      0.974492
# 29469  42953450                  0                 0.488233      0.974492
# 29470  42953461                  1                 0.411765      0.584245
# 29471  42953501                  0                 0.488233      0.974492
#
# ...

# %%
df.drop(['Industy Type' , 'city' , 'Industry Sector'] , axis=1)
# Out:
#         appl_id  TOT_UNSEC_ENQ_12M  lac2_ln_live_enq_rat_2y  BAL_SAMT_OVR  \
# 0      14089715                  6                 0.333333      0.868034
# 1      14089716                  1                 0.500000      0.145975
# 2      14089720                  3                 0.333333      0.519140
# 3      14094736                 10                 0.900000      0.270773
# 4      14096549                  6                 0.250000      0.000000
# ...         ...                ...                      ...           ...
# 29467  42953070                  0                 0.488233      0.974492
# 29468  42953299                  6                 0.000000      0.974492
# 29469  42953450                  0                 0.488233      0.974492
# 29470  42953461                  1                 0.411765      0.584245
# 29471  42953501                  0                 0.488233      0.974492
#
#        CURR_LIABI__C_PY  AGE_IN_BUREAU     BTO  industry_bin  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         appl_id  TOT_UNSEC_ENQ_12M  lac2_ln_live_enq_rat_2y  BAL_SAMT_OVR  \
# 0      14089715                  6                 0.333333      0.868034
# 1      14089716                  1                 0.500000      0.145975
# 2      14089720                  3                 0.333333      0.519140
# 3      14094736                 10                 0.900000      0.270773
# 4      14096549                  6                 0.250000      0.000000
# ...         ...                ...                      ...           ...
# 29467  42953070                  0                 0.488233      0.974492
# 29468  42953299                  6                 0.000000      0.974492
# 29469  42953450                  0                 0.488233      0.974492
# 29470  42953461                  1                 0.411765      0.584245
# 29471  42953501                  0                 0.488233      0.974492
#
# ...

# %%
print(df.isnull().sum())
# Out:
# appl_id                        0
# TOT_UNSEC_ENQ_12M              0
# lac2_ln_live_enq_rat_2y        0
# BAL_SAMT_OVR                   0
# CURR_LIABI__C_PY               0
# AGE_IN_BUREAU                  0
# BTO                            0
# industry_bin                   0
# asset_turnover_rat_rat         0
# lac2_ln_enq_amt_rat_5y         0
# TM_SN_FIRST_LIVE_5lac          0
# TM_SN_FIRST_LOAN_CC            0
# BAL_SAMT_lastloan              0
# TOT_5lac_enq_amt_12m           0
# NET_WORTH__C_rat               0
# bor_sales_rat_cy               0
# WOR_CAPITAL_GAP__C_avg         0
# AVG_INT_PURCH_DAYS_pl_2y       0
# city                           0
# Industy Type                2708
# Industry Sector                0
# Risk Score                     0
# dtype: int64

# %%
df.tail
# Out:
# <bound method NDFrame.tail of         appl_id  TOT_UNSEC_ENQ_12M  lac2_ln_live_enq_rat_2y  BAL_SAMT_OVR  \
# 0      14089715                  6                 0.333333      0.868034
# 1      14089716                  1                 0.500000      0.145975
# 2      14089720                  3                 0.333333      0.519140
# 3      14094736                 10                 0.900000      0.270773
# 4      14096549                  6                 0.250000      0.000000
# ...         ...                ...                      ...           ...
# 29467  42953070                  0                 0.488233      0.974492
# 29468  42953299                  6                 0.000000      0.974492
# 29469  42953450                  0                 0.488233      0.974492
# 29470  42953461                  1                 0.411765      0.584245
# 29471  42953501                  0                 0.488233      0.974492
#
# ...

# %%
df.head(20)
# Out:
#      appl_id  TOT_UNSEC_ENQ_12M  lac2_ln_live_enq_rat_2y  BAL_SAMT_OVR  \
# 0   14089715                  6                 0.333333      0.868034
# 1   14089716                  1                 0.500000      0.145975
# 2   14089720                  3                 0.333333      0.519140
# 3   14094736                 10                 0.900000      0.270773
# 4   14096549                  6                 0.250000      0.000000
# 5   14104240                  6                 0.166667      0.974492
# 6   14109886                  2                 0.200000      0.616970
# 7   14110033                  6                 0.156250      0.559220
# 8   14110058                  8                 0.281250      0.610702
# 9   14110404                 12                 0.900000      0.707034
# 10  14110406                 10                 0.289474      0.897528
# 11  14110422                  8                 0.153846      0.367116
# ...

# %%
y = np.array(['Risk Score']).reshape((-1, 1))

# %%
y.shape
# Out:
# (1, 1)

# %%
x.shape
# Out:
# (29472, 21)

# %%
plt.scatter(df['TOT_UNSEC_ENQ_12M'] , df['Risk Score'], color='red')
plt.title('Number of unsecured enquiries in last 12 months Vs Risk Score', fontsize=14)
plt.xlabel('Number of unsecured enquiries in last 12 months', fontsize=20)
plt.ylabel('Risk Score', fontsize=20)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['lac2_ln_live_enq_rat_2y'] , df['Risk Score'], color='red')
plt.title('ratio of live loan  to enquired loans in last 2 years Vs Risk Score', fontsize=14)
plt.xlabel('ratio of live loan  to enquired loans in last 2 years(with sanctioned amount greater than 2 Lakh)', fontsize=20)
plt.ylabel('Risk Score', fontsize=20)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['BAL_SAMT_OVR'] , df['Risk Score'], color='red')
plt.title('Balance/ Sanctioned Amount Vs Risk Score', fontsize=14)
plt.xlabel('Balance/ Sanctioned Amount', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['CURR_LIABI__C_PY'] , df['Risk Score'], color='red')
plt.title('Current Liabilities of Previous Year Vs Risk Score', fontsize=14)
plt.xlabel('Current Liabilities of Previous Year', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['AGE_IN_BUREAU'] , df['Risk Score'], color='red')
plt.title('Bureau Vintage Vs Risk Score', fontsize=14)
plt.xlabel('Bureau Vintage', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['TM_SN_FIRST_LIVE_5lac'] , df['Risk Score'], color='red')
plt.title('Time since first live loan(greater than 5 lakh sanctioned amount)', fontsize=14)
plt.xlabel('Time since first live loan(greater than 5 lakh sanctioned amount) ', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['TM_SN_FIRST_LOAN_CC'] , df['Risk Score'], color='red')
plt.title('Time since first Credit Card Vs Risk Score', fontsize=14)
plt.xlabel('Time since first Credit Card ', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['BTO'] , df['Risk Score'], color='red')
plt.title('Banking Turnover Vs Risk Score', fontsize=14)
plt.xlabel('Banking Turnover ', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['industry_bin'] , df['Risk Score'], color='red')
plt.title('Binning of Industry based on badrate Vs Risk Score', fontsize=14)
plt.xlabel('Binning of Industry based on badrate ', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['asset_turnover_rat_rat'] , df['Risk Score'], color='red')
plt.title('Ratio of asset turnover of Previous Year to Current Year Vs Risk Score', fontsize=14)
plt.xlabel('Ratio of asset turnover of Previous Year to Current Year ', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['BAL_SAMT_lastloan'] , df['Risk Score'], color='red')
plt.title('Balance/ Sanctioned Amount of last latest loan) Vs Risk Score', fontsize=14)
plt.xlabel('Balance/ Sanctioned Amount of last latest loan', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['lac2_ln_enq_amt_rat_5y'] , df['Risk Score'], color='red')
plt.title('ratio of loan amount to enquired amount in last 5 years(with sanctioned amount greater than 2 Lakh) Vs Risk Score', fontsize=14)
plt.xlabel('ratio of loan amount to enquired amount in last 5 years(with sanctioned amount greater than 2 Lakh) ', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['TOT_5lac_enq_amt_12m'] , df['Risk Score'], color='red')
plt.title('Enquiry amount in last 12 months(loans greater than 5 Lakh amount)) Vs Risk Score', fontsize=14)
plt.xlabel('Enquiry amount in last 12 months(loans greater than 5 Lakh amount)', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['NET_WORTH__C_rat'] , df['Risk Score'], color='red')
plt.title('Ratio of net worth of Previous Year to Current Year Vs Risk Score', fontsize=14)
plt.xlabel('Ratio of net worth of Previous Year to Current Year', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['bor_sales_rat_cy'] , df['Risk Score'], color='red')
plt.title('Borrowings to sales ratio of Current Year Vs Risk Score', fontsize=14)
plt.xlabel('Borrowings to sales ratio of Current Year', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['WOR_CAPITAL_GAP__C_avg'] , df['Risk Score'], color='red')
plt.title('Average working capital gap of current year and previous year Vs Risk Score', fontsize=14)
plt.xlabel('Average working capital gap of current year and previous year', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['AVG_INT_PURCH_DAYS_pl_2y'] , df['Risk Score'], color='red')
plt.title('Average inter purchase days of Personal Loan in last two years Vs Risk Score', fontsize=14)
plt.xlabel('Average inter purchase days of Personal Loan in last two years', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
plt.scatter(df['city'] , df['Risk Score'], color='red')
plt.title('City of customer Vs Risk Score', fontsize=14)
plt.xlabel('City of customer', fontsize=15)
plt.ylabel('Risk Score', fontsize=15)
plt.grid(True)
plt.show()

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['TOT_UNSEC_ENQ_12M', 'lac2_ln_live_enq_rat_2y', 'BAL_SAMT_OVR' , 'CURR_LIABI__C_PY' , 'AGE_IN_BUREAU' , 'BTO' , 'industry_bin' ,
       'asset_turnover_rat_rat' , 'lac2_ln_enq_amt_rat_5y' , 'TM_SN_FIRST_LIVE_5lac' , 'TM_SN_FIRST_LOAN_CC' , 'BAL_SAMT_lastloan' , 'TOT_5lac_enq_amt_12m' ,
       'NET_WORTH__C_rat' , 'bor_sales_rat_cy' , 'WOR_CAPITAL_GAP__C_avg' , 'AVG_INT_PURCH_DAYS_pl_2y']]

scaledX = scale.fit_transform(X)

print(scaledX)
# Out:
# [[-1.07340614e-01 -2.80218790e-01 -1.31075074e-03 ...  5.81425112e-02
#    1.27213596e+00  3.83303398e-16]
#  [-6.49414391e-01  2.12869041e-02 -1.02010223e-02 ... -2.63526321e-01
#   -5.49696197e-01  3.83303398e-16]
#  [-4.32584880e-01 -2.80218790e-01 -5.60646636e-03 ...  9.87826873e-03
#    9.07769529e-01  3.83303398e-16]
#  ...
#  [-7.57829146e-01  7.02950983e-15 -1.77703493e-17 ...  1.14703052e+00
#    0.00000000e+00  3.83303398e-16]
#  [-6.49414391e-01 -1.38333757e-01 -4.80486762e-03 ...  1.63477637e+00
#    0.00000000e+00  3.83303398e-16]
#  [-7.57829146e-01  7.02950983e-15 -1.77703493e-17 ...  7.23642805e-01
#    1.63650239e+00  3.83303398e-16]]

# %%
X = df[['TOT_UNSEC_ENQ_12M', 'lac2_ln_live_enq_rat_2y', 'BAL_SAMT_OVR' , 'CURR_LIABI__C_PY' , 'AGE_IN_BUREAU' , 'BTO' , 'industry_bin' ,
       'asset_turnover_rat_rat' , 'lac2_ln_enq_amt_rat_5y' , 'TM_SN_FIRST_LIVE_5lac' , 'TM_SN_FIRST_LOAN_CC' , 'BAL_SAMT_lastloan' , 'TOT_5lac_enq_amt_12m' ,
       'NET_WORTH__C_rat' , 'bor_sales_rat_cy' , 'WOR_CAPITAL_GAP__C_avg' , 'AVG_INT_PURCH_DAYS_pl_2y']]
y = df['Risk Score']

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  792.054929797278
# Coefficients:
#  [-3.34320059e+00  2.19394521e+01 -4.91257898e-03  5.55929655e+00
#   4.65488464e+00  1.06967615e-01 -2.81328287e+01 -5.73258802e-05
#   2.55159892e+00  1.04120986e-02 -1.56431144e-05 -2.86356254e-05
#  -6.15138277e+00 -1.92352700e+00 -4.59500532e+00 -4.14112128e+00
#  -1.93548405e-02]

# %%
import pandas
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

X = df[['TOT_UNSEC_ENQ_12M', 'lac2_ln_live_enq_rat_2y', 'BAL_SAMT_OVR' , 'CURR_LIABI__C_PY' , 'AGE_IN_BUREAU' , 'BTO' , 'industry_bin' ,
       'asset_turnover_rat_rat' , 'lac2_ln_enq_amt_rat_5y' , 'TM_SN_FIRST_LIVE_5lac' , 'TM_SN_FIRST_LOAN_CC' , 'BAL_SAMT_lastloan' , 'TOT_5lac_enq_amt_12m' ,
       'NET_WORTH__C_rat' , 'bor_sales_rat_cy' , 'WOR_CAPITAL_GAP__C_avg' , 'AVG_INT_PURCH_DAYS_pl_2y']]

scaledX = scale.fit_transform(X)
print(scaledX)
# Out:
# [[-1.07340614e-01 -2.80218790e-01 -1.31075074e-03 ...  5.81425112e-02
#    1.27213596e+00  3.83303398e-16]
#  [-6.49414391e-01  2.12869041e-02 -1.02010223e-02 ... -2.63526321e-01
#   -5.49696197e-01  3.83303398e-16]
#  [-4.32584880e-01 -2.80218790e-01 -5.60646636e-03 ...  9.87826873e-03
#    9.07769529e-01  3.83303398e-16]
#  ...
#  [-7.57829146e-01  7.02950983e-15 -1.77703493e-17 ...  1.14703052e+00
#    0.00000000e+00  3.83303398e-16]
#  [-6.49414391e-01 -1.38333757e-01 -4.80486762e-03 ...  1.63477637e+00
#    0.00000000e+00  3.83303398e-16]
#  [-7.57829146e-01  7.02950983e-15 -1.77703493e-17 ...  7.23642805e-01
#    1.63650239e+00  3.83303398e-16]]

# %%
X = scaledX

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
# Out:
# Intercept:
#  704.9319353963084
# Coefficients:
#  [-3.08371363e+01  1.21277157e+01 -3.98994734e-01  1.56883724e+01
#   2.33861619e+01  1.00068420e+01 -2.52024043e+01 -3.79832528e-02
#   9.84515682e-01  9.28045645e+00 -2.43215135e-02 -1.34075185e-01
#  -1.56140947e+01 -5.41964930e+00 -2.09882398e+00 -1.13652656e+01
#  -5.74059771e+00]

# %%
# tkinter GUI
import tkinter as tk 
root= tk.Tk()

# %%
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

# %%
canvas1 = tk.Canvas(root, width = 500, height = 300)
canvas1.pack()

# %%
# with sklearn
Intercept_result = ('Intercept: ', regr.intercept_)
label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
canvas1.create_window(260, 220, window=label_Intercept)
# Out:
# 1

# %%
# with sklearn
Coefficients_result  = ('Coefficients: ', regr.coef_)
label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
canvas1.create_window(260, 240, window=label_Coefficients)
# Out:
# 2

# %%
# New_Bureau Vintage Label and input box
label1 = tk.Label(root, text='Type Bureau Vintage: ')
canvas1.create_window(100, 100, window=label1)
# Out:
# 5

# %%
entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)
# Out:
# 4

# %%
# NewBanking Turnove label and input box
label2 = tk.Label(root, text=' Type Banking Turnover: ')
canvas1.create_window(120, 120, window=label2)
# Out:
# 6

# %%
entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)
# Out:
# 7

# %%
# with statsmodels
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Risk Score   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     3293.
# Date:                Mon, 02 Aug 2021   Prob (F-statistic):               0.00
# Time:                        17:26:04   Log-Likelihood:            -1.5189e+05
# No. Observations:               29472   AIC:                         3.038e+05
# Df Residuals:                   29454   BIC:                         3.040e+05
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        704.9319      0.244   2888.626      0.000     704.454     705.410
# ...

# %%
y_pred = LinearRegression.predict(print_model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-185-a3acec320551> in <module>
# ----> 1 y_pred = LinearRegression.predict(print_model)
#
# TypeError: predict() missing 1 required positional argument: 'X'

# %%
r_sq = model.score(X, y)
>>> print('coefficient of determination:', r_sq)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-186-2379327f5eff> in <module>
# ----> 1 r_sq = model.score(X, y)
#       2 print('coefficient of determination:', r_sq)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\base\wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'OLSResults' object has no attribute 'score'

# %%
# prediction with sklearn
New_Age_Bureau = 4.4
New_BTO_Rate = 15.3
New_TOT_UNSEC_ENQ_12M = 2
New_lac2_ln_live_enq_rat_2y = 15 
New_BAL_SAMT_OVR = 10
New_CURR_LIABI__C_PY =  14
New_industry_bin = 7
New_asset_turnover_rat_rat = 6
New_lac2_ln_enq_amt_rat_5y = 66
New_TM_SN_FIRST_LIVE_5lac = 6
New_TM_SN_FIRST_LOAN_CC = 77
New_BAL_SAMT_lastloan = 78
New_TOT_5lac_enq_amt_12m = 99
New_NET_WORTH__C_rat = 8
New_bor_sales_rat_cy = 9
New_WOR_CAPITAL_GAP__C_avg = 9
New_AVG_INT_PURCH_DAYS_pl_2y = 9
print ('Predicted Risk Score: \n', regr.predict([[New_Age_Bureau , New_BTO_Rate, New_TOT_UNSEC_ENQ_12M, New_lac2_ln_live_enq_rat_2y , 
    New_BAL_SAMT_OVR , New_CURR_LIABI__C_PY , New_industry_bin , New_asset_turnover_rat_rat , New_lac2_ln_enq_amt_rat_5y , New_TM_SN_FIRST_LIVE_5lac , 
    New_TM_SN_FIRST_LOAN_CC , New_BAL_SAMT_lastloan , New_TOT_5lac_enq_amt_12m , New_NET_WORTH__C_rat , New_bor_sales_rat_cy , New_WOR_CAPITAL_GAP__C_avg , New_AVG_INT_PURCH_DAYS_pl_2y]]))
# Out:
# Predicted Risk Score:
#  [-467.0217399]

# %%
# with statsmodels
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             Risk Score   R-squared:                       0.655
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     3293.
# Date:                Mon, 02 Aug 2021   Prob (F-statistic):               0.00
# Time:                        18:11:01   Log-Likelihood:            -1.5189e+05
# No. Observations:               29472   AIC:                         3.038e+05
# Df Residuals:                   29454   BIC:                         3.040e+05
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        704.9319      0.244   2888.626      0.000     704.454     705.410
# ...

# %%
# tkinter GUI
root= tk.Tk()

canvas1 = tk.Canvas(root, width = 500, height = 300)
canvas1.pack()

# with sklearn
Intercept_result = ('Intercept: ', regr.intercept_)
label_Intercept = tk.Label(root, text=Intercept_result, justify = 'center')
canvas1.create_window(260, 220, window=label_Intercept)

# with sklearn
Coefficients_result  = ('Coefficients: ', regr.coef_)
label_Coefficients = tk.Label(root, text=Coefficients_result, justify = 'center')
canvas1.create_window(260, 240, window=label_Coefficients)

# New_Age_Bureau label and input box
label1 = tk.Label(root, text='Type Interest Rate: ')
canvas1.create_window(100, 100, window=label1)

entry1 = tk.Entry (root) # create 1st entry box
canvas1.create_window(270, 100, window=entry1)

# New_BTO_Rate label and input box
label2 = tk.Label(root, text=' Type Unemployment Rate: ')
canvas1.create_window(120, 120, window=label2)

entry2 = tk.Entry (root) # create 2nd entry box
canvas1.create_window(270, 120, window=entry2)


def values(): 
    global New_Interest_Rate #our 1st input variable
    New_Interest_Rate = float(entry1.get()) 
    
    global New_Unemployment_Rate #our 2nd input variable
    New_Unemployment_Rate = float(entry2.get()) 
    
    Prediction_result  = ('Predicted Stock Index Price: ', regr.predict([[New_Interest_Rate ,New_Unemployment_Rate]]))
    label_Prediction = tk.Label(root, text= Prediction_result, bg='orange')
    canvas1.create_window(260, 280, window=label_Prediction)
    
button1 = tk.Button (root, text='Predict Stock Index Price',command=values, bg='orange') # button to call the 'values' command above 
canvas1.create_window(270, 150, window=button1)
 
#plot 1st scatter 
figure3 = plt.Figure(figsize=(5,4), dpi=100)
ax3 = figure3.add_subplot(111)
ax3.scatter(df['Interest_Rate'].astype(float),df['Stock_Index_Price'].astype(float), color = 'r')
scatter3 = FigureCanvasTkAgg(figure3, root) 
scatter3.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax3.legend(['Stock_Index_Price']) 
ax3.set_xlabel('Interest Rate')
ax3.set_title('Interest Rate Vs. Stock Index Price')

#plot 2nd scatter 
figure4 = plt.Figure(figsize=(5,4), dpi=100)
ax4 = figure4.add_subplot(111)
ax4.scatter(df['Unemployment_Rate'].astype(float),df['Stock_Index_Price'].astype(float), color = 'g')
scatter4 = FigureCanvasTkAgg(figure4, root) 
scatter4.get_tk_widget().pack(side=tk.RIGHT, fill=tk.BOTH)
ax4.legend(['Stock_Index_Price']) 
ax4.set_xlabel('Unemployment_Rate')
ax4.set_title('Unemployment_Rate Vs. Stock Index Price')

root.mainloop()
